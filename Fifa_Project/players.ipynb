# %% [markdown]
# # Fifa Player Analysis

# %% [markdown]
# ### Imports & Loading in CSV

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df = pd.read_csv("players_20.csv")

# %% [markdown]
# ## Overall Analysis

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
#looking at all columns to see what type of data we have
df.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %%
# Getting an overview of the data and how many rows and columns we have
df.describe
# Out:
# <bound method NDFrame.describe of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
#players in each country

player_country = df[['sofifa_id', 'nationality']]
player_country.head(5)
# Out:
#    sofifa_id nationality
# 0     158023   Argentina
# 1      20801    Portugal
# 2     190871      Brazil
# 3     200389    Slovenia
# 4     183277     Belgium

# %%
country_list = player_country['nationality'].unique()
country_list.sort()
country_list
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua & Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Barbados', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bolivia', 'Bosnia Herzegovina', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Rep.', 'Chad', 'Chile', 'China PR',
#        'Chinese Taipei', 'Colombia', 'Comoros', 'Congo', 'Costa Rica',
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'DR Congo', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Ethiopia', 'FYR Macedonia', 'Faroe Islands', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Gibraltar', 'Greece', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong',
# ...

# %%
#there are 162 unique countries in the dataset
len(country_list)
# Out:
# 162

# %%
#number of players in each country
count_by_country = player_country.groupby(by='nationality').count().rename(columns={'sofifa_id':'player_count'})
count_by_country.head(5)
# Out:
#                    player_count
# nationality
# Afghanistan                   2
# Albania                      43
# Algeria                      50
# Angola                       16
# Antigua & Barbuda             7

# %%
#Top 10 player counts
count_by_country = count_by_country.sort_values(by='player_count', ascending=False)
count_by_country.head(10)
# Out:
#              player_count
# nationality
# England              1667
# Germany              1216
# Spain                1035
# France                984
# Argentina             886
# Brazil                824
# Italy                 732
# Colombia              591
# Japan                 453
# Netherlands           416

# %%
#top 5 countries with the most players bar plot
top_count_plot = count_by_country.sort_values(by='player_count', ascending=False).head(5).reset_index()
top_count_plot.plot.bar(x='nationality', y='player_count', color="green")
plt.show()

# %%
df['overall'].unique()
# Out:
# array([94, 93, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78,
#        77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61,
#        60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48], dtype=int64)

# %%
#top 5 players by overall score
top_players = df[['sofifa_id', 'short_name', 'wage_eur', 'overall']].sort_values(by='overall', ascending=False)
top_players.head(5)
# Out:
#    sofifa_id         short_name  wage_eur  overall
# 0     158023           L. Messi    565000       94
# 1      20801  Cristiano Ronaldo    405000       93
# 2     190871          Neymar Jr    290000       92
# 3     200389           J. Oblak    125000       91
# 4     183277          E. Hazard    470000       91

# %% [markdown]
# ## Top 5 Salaries

# %%
#top 5 player salaries
top_salaries = top_players[['sofifa_id', 'short_name', 'wage_eur']].sort_values(by='wage_eur', ascending=False)
top_salaries.head(5)
# Out:
#     sofifa_id         short_name  wage_eur
# 0      158023           L. Messi    565000
# 4      183277          E. Hazard    470000
# 1       20801  Cristiano Ronaldo    405000
# 5      192985       K. De Bruyne    370000
# 22     194765       A. Griezmann    370000

# %%
#top 5 player salaries bar plot
top_salaries_plot = top_salaries.head(5).reset_index()

# function to add formatting for labels on bars
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i]//2,y[i], ha = 'center')
        
x = top_salaries_plot['short_name']
y = top_salaries_plot['wage_eur']

plt.figure(figsize=(10,6))
bar_chart = plt.bar(x, y)
addlabels(x, y)

# giving title to the plot
plt.title("Top 5 Player Salaries")
    
# giving X and Y labels
plt.xlabel("Short Name")
plt.ylabel("Salary (EUR)")

plt.show()

# %% [markdown]
# ## Germany Analysis

# %%
# Top 10 German player records
top10_germany = df.loc[df["nationality"]=="Germany"].sort_values(by="overall", ascending = False).head(10)
top10_germany
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 122     192563  https://sofifa.com/player/192563/bernd-leno/20...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# ...

# %%
#Top 5 German Heights
top5_german_heights = df.loc[df["nationality"]=="Germany"].sort_values(by="height_cm", ascending=False).head(5)
top5_german_heights
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  overall  potential  \
# ...

# %%
#Top 5 German Weights
top5_german_weights = df.loc[df["nationality"]=="Germany"].sort_values(by="weight_kg", ascending=False).head(5)
top5_german_weights
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  overall  potential  value_eur  \
# ...

# %%
#Top 5 German Wages
top5_german_wages = df.loc[df["nationality"]=="Germany"].sort_values(by="wage_eur", ascending=False).head(5)
top5_german_wages
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  overall  potential  value_eur  \
# ...

# %%
#Top 5 German Wages dataframe by short name, wage
top5_german_wages = top5_german_wages[["short_name", "wage_eur"]]
top5_german_wages
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %% [markdown]
# ## Top 5 Shooters & Defenders

# %%
#Top 5 best shooters with short names

#To ensure i'm only getting records of those with short names as instructed, I use the dropna with short_name as the subset to drop the na records
top5_shooters = df[["sofifa_id","short_name","shooting"]].dropna(subset=['short_name']).sort_values(by="shooting", ascending=False).head(5)
top5_shooters
# Out:
#      sofifa_id         short_name  shooting
# 1        20801  Cristiano Ronaldo      93.0
# 0       158023           L. Messi      92.0
# 12      202126            H. Kane      91.0
# 17      153079          S. Agüero      90.0
# 205     159261    F. Quagliarella      89.0

# %%
#Top 5 best defender player records
top5_defenders = df[["sofifa_id","short_name","defending","nationality","club"]].sort_values(by="defending", ascending=False).head(5)
top5_defenders
# Out:
#     sofifa_id    short_name  defending  nationality               club
# 16     138956  G. Chiellini       90.0        Italy           Juventus
# 7      203376   V. van Dijk       90.0  Netherlands          Liverpool
# 11     201024  K. Koulibaly       89.0      Senegal             Napoli
# 35     182493      D. Godín       89.0      Uruguay              Inter
# 49     178603    M. Hummels       89.0      Germany  Borussia Dortmund

# %% [markdown]
# ## Real Madrid Analysis

# %%
#Making a dataframe for Real Madrid team top 5 player queries

#Based on instruction, we will be doing analysis on shooting and defending stats, so I will dropna based on those subset columns since there are missing statistics
top5_realmadrid_df = df.loc[df["club"]=="Real Madrid"].sort_values(by="overall", ascending=False).dropna(subset=["shooting", "defending"]).head(5)
top5_realmadrid_df.head(5)
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 42     200145  https://sofifa.com/player/200145/carlos-henriq...
#
#       short_name                          long_name  age         dob  \
# 4      E. Hazard                        Eden Hazard   28  1991-01-07
# 8      L. Modrić                        Luka Modrić   33  1985-09-09
# 18  Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 36      T. Kroos                         Toni Kroos   29  1990-01-04
# 42      Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
#
#     height_cm  weight_kg nationality         club  overall  potential  \
# 4         175         74     Belgium  Real Madrid       91         91
# ...

# %%
top5_realmadrid_wages = top5_realmadrid_df[["sofifa_id", "short_name", "wage_eur"]].sort_values(by="wage_eur", ascending=False).head(5)
top5_realmadrid_wages
# Out:
#     sofifa_id    short_name  wage_eur
# 4      183277     E. Hazard    470000
# 8      177003     L. Modrić    340000
# 36     182521      T. Kroos    330000
# 18     155862  Sergio Ramos    300000
# 42     200145      Casemiro    240000

# %%
top5_realmadrid_shooters = top5_realmadrid_df[["sofifa_id", "short_name", "shooting"]].sort_values(by="shooting", ascending=False).dropna().head(5)
top5_realmadrid_shooters
# Out:
#     sofifa_id    short_name  shooting
# 4      183277     E. Hazard      83.0
# 36     182521      T. Kroos      80.0
# 8      177003     L. Modrić      76.0
# 42     200145      Casemiro      72.0
# 18     155862  Sergio Ramos      68.0

# %%
top5_realmadrid_defenders = top5_realmadrid_df[["sofifa_id", "short_name", "defending"]].sort_values(by="defending", ascending=False).head(5)
top5_realmadrid_defenders
# Out:
#     sofifa_id    short_name  defending
# 18     155862  Sergio Ramos       87.0
# 42     200145      Casemiro       85.0
# 8      177003     L. Modrić       72.0
# 36     182521      T. Kroos       70.0
# 4      183277     E. Hazard       35.0

# %%
top5_realmadrid_nationalities = top5_realmadrid_df[["sofifa_id", "short_name", "nationality"]]
top5_realmadrid_nationalities
# Out:
#     sofifa_id    short_name nationality
# 4      183277     E. Hazard     Belgium
# 8      177003     L. Modrić     Croatia
# 18     155862  Sergio Ramos       Spain
# 36     182521      T. Kroos     Germany
# 42     200145      Casemiro      Brazil
